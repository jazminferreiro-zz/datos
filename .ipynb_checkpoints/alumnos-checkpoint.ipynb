# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
math_data = pd.read_csv('/home/jaz/Escritorio/jaz/fiuba/orga-de-datos-7506/guia1/student-mat.csv')
port_data = pd.read_csv('/home/jaz/Escritorio/jaz/fiuba/orga-de-datos-7506/guia1/student-por.csv')

# %%
math_data.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390 ...      5        5      4     4     5      4       11   9   9   9
# 391 ...      2        4      5     3     4      2        3  14  16  16
# 392 ...      5        5      3     3     3      3        3  10   8   7
# 393 ...      4        4      1     3     4      5        0  11  12  10
# 394 ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
port_data.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#     ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 644 ...      5        4      2     1     2      5        4  10  11  10
# 645 ...      4        3      4     1     1      1        4  15  15  16
# 646 ...      1        1      1     1     1      5        6  11  12   9
# 647 ...      2        4      5     3     4      2        6  10  10  10
# 648 ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
port_data.shape
# Out:
# (649, 33)

# %%
math_data.shape
# Out:
# (395, 33)

# %%
port_data.columns.values
# Out:
# array(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime',
#        'studytime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1',
#        'G2', 'G3'], dtype=object)

# %%
port_data.columns.values.tolist() == math_data.columns.values.tolist()
# Out:
# True

# %%
port_data = port_data.rename(columns={'G1':'G1_portugues'})
port_data = port_data.rename(columns={'G2':'G2_portugues'})
port_data = port_data.rename(columns={'G3':'G3_portugues'})
port_data = port_data.rename(columns={'paid':'paid_portugues'})
port_data = port_data.rename(columns={'failures':'failures_portugues'})

math_data = math_data.rename(columns={'G1':'G1_mate'})
math_data = math_data.rename(columns={'G2':'G2_mate'})
math_data = math_data.rename(columns={'G3':'G3_mate'})
math_data = math_data.rename(columns={'paid':'paid_mate'})
math_data = math_data.rename(columns={'failures':'failures_mate'})

# %%
#hay 100 alumnos que estan en las dos clases
intersection = pd.merge(port_data,math_data,how='inner', on=['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
       'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime',
       'studytime', 'schoolsup', 'famsup',
       'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
       'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences'])
intersection.shape
# Out:
# (100, 38)

# %%
#todos los alumnos sin repetir los cien que van a las dos clases
students = pd.merge(port_data,math_data,how='outer', on=['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu',
       'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime',
       'studytime', 'schoolsup', 'famsup',
       'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
       'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences'])
students.shape
# Out:
# (944, 38)

# %%
students['promedio_mate']= (students.G1_mate*5 +students.G2_mate*5 + students.G3_mate*5)/3
students['promedio_portugues']= ( students.G1_portugues*5+students.G2_portugues*5+students.G3_portugues*5 )/3
students.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 939     MS   M   20       U     LE3       A     2     2  services  services
# 940     MS   M   17       U     LE3       T     3     1  services  services
# 941     MS   M   21       R     GT3       T     1     1     other     other
# 942     MS   M   18       R     LE3       T     3     2  services     other
# 943     MS   M   19       U     LE3       T     1     1     other   at_home
#
#            ...         G1_portugues G2_portugues  G3_portugues  failures_mate  \
# 939        ...                  NaN          NaN           NaN            2.0
# 940        ...                  NaN          NaN           NaN            0.0
# 941        ...                  NaN          NaN           NaN            3.0
# 942        ...                  NaN          NaN           NaN            0.0
# 943        ...                  NaN          NaN           NaN            0.0
#
# ...

# %%
import numpy as np
def promedio_total(row):
   if (np.isnan(row['promedio_portugues'])):
      return row['promedio_mate']
   else:
    if(np.isnan(row['promedio_mate'])):
           return row['promedio_portugues']
    else:
            return (row.promedio_portugues + row.promedio_mate) /2
        
students['promedio_total'] =students.apply(lambda row: promedio_total(row),axis=1)
students
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
#Existe una dependencia entre las notas obtenidas y la cantidad de aplazos previos?
grades = students.loc[:,['failures_portugues','promedio_portugues','failures_mate','promedio_mate','promedio_total']]
grades.plot.scatter('failures_portugues','promedio_portugues',alpha=0.25,figsize=(12,8));

# %%
grades.groupby('failures_portugues').mean()['promedio_portugues'].plot(figsize=(14,4));

# %%
grades['promedio_mate']= (students.G1_mate*5 +students.G2_mate*5 + students.G3_mate*5)/3
grades.plot.scatter('failures_mate','promedio_mate',alpha=0.25,figsize=(12,8));

# %%
grades.groupby('failures_mate').mean()['promedio_mate'].plot(figsize=(14,4));

# %%
grades['failures_mate'].corr(grades['promedio_mate'])
# Out:
# -0.37575889592699557

# %%
grades['failures_portugues'].corr(grades['promedio_portugues'])
# Out:
# -0.40581460262949232

# %%
fig, ax = plt.subplots(figsize=(16,8))         # Sample figsize in inches
cor = grades.corr().abs()
cor.values[[np.arange(4)]*2] = 0
sns.heatmap(cor,cmap='Oranges');

#no parece haber mucha correlacion menos que la mitad

# %%
#Los alumnos con ambos padres en la casa tienen mejor desempeño que los padres que tienen un padre trabajando.
atHome = students.loc[(students.Mjob=='at_home') & (students.Fjob=='at_home' ),['Mjob','Fjob','failures_portugues','promedio_portugues','failures_mate','promedio_mate','promedio_total']]
notHome = students.loc[(students.Mjob != 'at_home') | (students.Fjob != 'at_home' ),['Mjob','Fjob','failures_portugues','promedio_portugues','failures_mate','promedio_mate','promedio_total']]

pd.DataFrame({'atHome': [atHome.failures_mate.mean(), atHome.promedio_mate.mean(), atHome.failures_portugues.mean(), atHome.promedio_portugues.mean(),atHome.promedio_total.mean()],
                    'notHOme': [notHome.failures_mate.mean(), notHome.promedio_mate.mean(), notHome.failures_portugues.mean(), notHome.promedio_portugues.mean(),notHome.promedio_total.mean() ]},
                       index=['failures_mate','promedio_mate','failures_portugues','promedio_portugues','promedio_total'])
# Out:
#                        atHome    notHOme
# failures_mate        0.142857   0.337629
# promedio_mate       65.952381  53.170103
# failures_portugues   0.388889   0.217116
# promedio_portugues  57.685185  58.137876
# promedio_total      58.586957  55.855049

# %%
perentsJob = students.loc[:,['Mjob','Fjob','failures_portugues','promedio_portugues','failures_mate','promedio_mate','promedio_total']]
perentsJob['both_atHome']=((perentsJob.Mjob=='at_home') & (perentsJob.Fjob=='at_home'))


perentsJob.head(8)
# Out:
#        Mjob      Fjob  failures_portugues  promedio_portugues  failures_mate  \
# 0   at_home   teacher                 0.0           36.666667            NaN
# 1   at_home     other                 0.0           51.666667            NaN
# 2   at_home     other                 0.0           61.666667            NaN
# 3    health  services                 0.0           70.000000            NaN
# 4     other     other                 0.0           61.666667            NaN
# 5  services     other                 0.0           61.666667            NaN
# 6     other     other                 0.0           63.333333            0.0
# 7     other   teacher                 0.0           60.000000            NaN
#
#    promedio_mate  promedio_total  both_atHome
# 0            NaN       36.666667        False
# 1            NaN       51.666667        False
# 2            NaN       61.666667        False
# 3            NaN       70.000000        False
# ...

# %%
perentsJob.groupby('both_atHome').mean()['promedio_total'].plot(figsize=(14,4));

# %%
perentsJob.plot.scatter('both_atHome','promedio_total',alpha=0.25,figsize=(12,8));

# %%
fig, ax = plt.subplots(figsize=(16,8))         # Sample figsize in inches
cor = perentsJob.corr().abs()
cor.values[[np.arange(4)]*2] = 0
sns.heatmap(cor,cmap='Oranges');

# %%
#El nivel de educación de los padres que viven juntos es levemente superior al de aquellos que viven separados.
perents= students.loc[:,['Pstatus','Medu','Fedu']]
perents.groupby('Pstatus').mean()['Medu'].plot(kind='bar',figsize=(14,4));

# %%
perents.boxplot('Fedu',by='Pstatus',figsize=(16,8),rot=90);
#es recontra falso

# %%
#Aquellos alumnos que se encuentran en una relación sentimental registran en promedio mayor consumo de alcohol
#tanto en la semana como durante el fin de semana.
alcohol= students.loc[:,['romantic','Walc','Dalc']]
promedio_romatic = alcohol.loc[alcohol.romantic.str.contains('yes', na=False),['Walc']].mean()
promedio_noRomantic = alcohol.loc[alcohol.romantic.str.contains('no', na=False),['Walc']].mean()
promedio_romatic > promedio_noRomantic
# Out:
# Walc    False
# dtype: bool

# %%
promedio_romantic = alcohol.loc[alcohol.romantic.str.contains('yes', na=False),['Dalc']].mean()
promedio_noRomantic = alcohol.loc[alcohol.romantic.str.contains('no', na=False),['Dalc']].mean()
promedio_romantic > promedio_noRomantic
# Out:
# Dalc    True
# dtype: bool

# %%
alcohol= students.loc[:,['romantic','Walc','Dalc']]
alcohol.boxplot('Walc',by='romantic',figsize=(16,8),rot=90);

# %%
alcohol.boxplot('Dalc',by='romantic',figsize=(16,8),rot=90);

# %%
#Los alumnos de la escuela Gabriel Pereira tienen mejor desempeño que los de la escuela Mousinho da Silveira, tanto para Matemática como para Portugués.
students.groupby(['school'])['promedio_mate'].mean()
# Out:
# school
# GP    53.686724
# MS    51.195652
# Name: promedio_mate, dtype: float64

# %%
students.groupby(['school'])['promedio_portugues'].mean()
# Out:
# school
# GP    61.178093
# MS    52.411504
# Name: promedio_portugues, dtype: float64

# %%
students['school_GP'] = students.school== 'GP'
students.plot.scatter('school_GP','promedio_portugues',alpha=0.25,figsize=(12,8));

# %%
students.groupby('school_GP').mean()['promedio_total'].plot(figsize=(14,4));

# %%
#Realizando un histograma de notas finales, se puede observar que existen mas notas entre 12 y 14 que entre 10 y 12.
math_data.G1_mate.append(math_data.G2_mate).append(math_data.G3_mate).append(port_data.G1_portugues).append(port_data.G2_portugues).append(port_data.G3_portugues)
from pandas import Series
## Histogram
notas_finales = notas.apply(lambda x: Series(x).value_counts()).sum()
notas_finales.plot(kind='bar',figsize=(12,8));

# %%
notas_finales.get(12) +notas_finales.get(13)+notas_finales.get(14) > notas_finales.get(10) +notas_finales.get(11)+notas_finales.get(12)
# Out:
# False

# %%
notas_finales.get(13)+notas_finales.get(14) > notas_finales.get(11)+notas_finales.get(12)
# Out:
# False

# %%
notas_finales.get(12) +notas_finales.get(13) > notas_finales.get(10) +notas_finales.get(11)
# Out:
# False

# %%
#Hay mas registros de alumnos de Matemática que de Portugués.
len(math_data.index)>len(port_data.index)
# Out:
# False

# %%
#Existen mas alumnos de Portugués en la escuela Mousinho da Silveira que en la Gabriel Pereira.
port_data.groupby(['school']).size()
# Out:
# school
# GP    423
# MS    226
# dtype: int64

# %%
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in students.groupby(['school']):
    ax.plot(group.promedio_portugues, group.promedio_mate, marker='o', linestyle='', ms=12, label=name)
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-36daba455de3> in <module>()
# ----> 1 fig, ax = plt.subplots()
#       2 ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
#       3 for name, group in students.groupby(['school']):
#       4     ax.plot(group.promedio_portugues, group.promedio_mate, marker='o', linestyle='', ms=12, label=name)
#       5 ax.legend()
#
# NameError: name 'plt' is not defined
